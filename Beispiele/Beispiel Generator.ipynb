# %%
import simpy

# %%
def mein_prozess(env: simpy.Environment):
    print(env.now)
    yield env.timeout(5)
    print(env.now)

# %%
env = simpy.Environment()
proc = env.process(mein_prozess(env))
print(f"")
env.run(until = 10)
# Out:
# 0
# 5
